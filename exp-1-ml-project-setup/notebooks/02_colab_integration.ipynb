# %% [markdown]
# # Exp 1: ML Project in Google Colab
#
# Run this notebook in Google Colab to prove reproducibility.

# %%
# Step 1: Clone repo
# !git clone https://github.com/Saksham-3175/mlops-lab.git
# %cd mlops-lab/exp-1-ml-project-setup

# %%
# Step 2: Install dependencies
# !pip install scikit-learn numpy pandas -q

# %%
# Step 3: Train model
import sys
sys.path.append('src')
from train import train_model
model, score = train_model()

# %%
# Step 4: Verify
from pathlib import Path
model_path = Path('models/iris_classifier.pkl')
print(f"✓ Model saved: {model_path.exists()}")
print(f"✓ Accuracy: {score:.4f}")
